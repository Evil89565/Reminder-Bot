# %%
# !pip install telebot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 kB 11.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import telebot
from telebot import types
import json

# %%
#Connect to Telegram

# %%
# prompt: connect to telegram

BOT_TOKEN = 'YOUR_BOT_TOKEN' # Replace with your bot token

bot = telebot.TeleBot(BOT_TOKEN)
print("Bot connected successfully")

# %%
# prompt: create empty dataframe with one column

# Create an empty DataFrame with one column named 'column1'
df = pd.DataFrame(columns=['Priority No.', 'To Do'])
df = df.set_index('Priority No.')
df
# Out:
# Empty DataFrame
# Columns: [To Do]
# Index: []

# %%
def insert_value(dataframe, value_to_insert):
    df = dataframe
    #Find the next available index
    next_index = 1
    if not df.empty:
      next_index = df.index.max() + 1
    # Create a new row with the next index and insert in column 2
    new_row = pd.DataFrame({'Priority No.':[next_index], 'To Do':[value_to_insert]})
    new_row = new_row.set_index('Priority No.')
    df = pd.concat([df, new_row])
    return df

# %%
insert_value(df, "world")
# Out:
#               To Do
# Priority No.
# 1              Test
# 2               why
# 3             hello
# 4             world

# %%
def change_row_order(dataframe, row_index, direction, change_val):
    df = dataframe.copy() # Create a copy to avoid modifying the original DataFrame
    if row_index not in df.index:
        return df, "Error: Row index not found."

    current_index = row_index
    new_index = current_index

    if direction.lower() == "up":
        new_index = current_index - change_val
    elif direction.lower() == "down":
        new_index = current_index + change_val
    else:
        return df, "Error: Invalid direction. Use 'up' or 'down'."

    if new_index in df.index:
      # Swap the rows
      df.loc[[current_index, new_index]] = df.loc[[new_index, current_index]].values
      return df, "Row order changed successfully."
    else:
      return df, "Error: Cannot move row further in this direction."

# Example usage (you'll likely call this from your bot's message handler)
# df = insert_value(df, "Task 1")
# df = insert_value(df, "Task 2")
# df = insert_value(df, "Task 3")
df, message = change_row_order(df, 1, "down", 2)
df
# print(message)
# Out:
#               To Do
# Priority No.
# 1              Test
# 2               why
# 3             hello

# %%
#Send message in morning

# %%
#Add New Tasks

# %%
#Take Input of Task Completion

# %%
#Save Completion in Log

# %%
#Refresh to Show New List
